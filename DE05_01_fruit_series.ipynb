# %% [markdown]
# <a href="https://colab.research.google.com/github/luckguy/DE_05/blob/main/DE05_01_fruit_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##範例 5-1: Series 建立

# %%
import pandas as pd

# %%
fruits = ["蘋果", "橘子", "梨子", "櫻桃"]
quantities = [15, 33, 45, 55]
s = pd.Series(quantities, index=fruits)
p = pd.Series([11, 16, 21, 32], index=fruits)
print('s=',s)
print('p=',p)
# Out:
# s= 蘋果    15
# 橘子    33
# 梨子    45
# 櫻桃    55
# dtype: int64
# p= 蘋果    11
# 橘子    16
# 梨子    21
# 櫻桃    32
# dtype: int64

# %%
print('s+p=',s + p)
print("總計=", sum(s + p))
# Out:
# s+p= 蘋果    26
# 橘子    49
# 梨子    66
# 櫻桃    87
# dtype: int64
# 總計= 228
